# %% [markdown]
# # Plot array geometry

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
# Import data:
stations_fname = "reftek_stations.txt"
stations_df = pd.read_csv(stations_fname)

# %%
stations_df
# Out:
#      Latitude  Longitude  Elevation  Name
# 0  -78.145699 -83.936903     321.67  A000
# 1  -78.145709 -83.936062     321.67  AS11
# 2  -78.145526 -83.936049     321.67  AS12
# 3  -78.145426 -83.938721     321.67  AS13
# 4  -78.145894 -83.937441     321.67  AS21
# 5  -78.146007 -83.936612     321.67  AS22
# 6  -78.145608 -83.934793     321.67  AS23
# 7  -78.145525 -83.937428     321.67  AS31
# 8  -78.145634 -83.938327     321.67  AS32
# 9  -78.146208 -83.937467     321.67  AS33
# 10 -78.143789 -83.917162     323.35  R102
# 11 -78.149787 -83.927611     323.38  R103
# 12 -78.147663 -83.956826     321.56  R104
# 13 -78.133495 -83.964508     316.60  R201
# 14 -78.146893 -83.871523     320.98  R202
# 15 -78.156722 -83.974556     323.73  R203

# %%
# Plot stations:
fig, ax = plt.subplots(figsize=(6,6))
ax.scatter(stations_df['Longitude'], stations_df['Latitude'])
for index, row in stations_df.iterrows():
    ax.text(row['Longitude'], row['Latitude'], row['Name'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="599.9999869953505">
